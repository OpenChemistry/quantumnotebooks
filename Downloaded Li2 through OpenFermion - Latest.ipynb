# %%
#
# Google data
#

data = ['0.20 2.8489 0.5678 -1.4508 0.6799 0.0791',
        '0.25 2.1868 0.5449 -1.2870 0.6719 0.0798', 
        '0.30 1.7252 0.5215 -1.1458 0.6631 0.0806', 
        '0.35 1.3827 0.4982 -1.0226 0.6537 0.0815', 
        '0.40 1.1182 0.4754 -0.9145 0.6438 0.0825',
        '0.45 0.9083 0.4534 -0.8194 0.6336 0.0835', 
        '0.50 0.7381 0.4325 -0.7355 0.6233 0.0846', 
        '0.55 0.5979 0.4125 -0.6612 0.6129 0.0858', 
        '0.60 0.4808 0.3937 -0.5950 0.6025 0.0870', 
        '0.65 0.3819 0.3760 -0.5358 0.5921 0.0883', 
        '0.70 0.2976 0.3593 -0.4826 0.5818 0.0896', 
        '0.75 0.2252 0.3435 -0.4347 0.5716 0.0910', 
        '0.80 0.1626 0.3288 -0.3915 0.5616 0.0925', 
        '0.85 0.1083 0.3149 -0.3523 0.5518 0.0939', 
        '0.90 0.0609 0.3018 -0.3168 0.5421 0.0954',
        '0.95 0.0193 0.2895 -0.2845 0.5327 0.0970',
        '1.00 -0.0172 0.2779 -0.2550 0.5235 0.0986', 
        '1.05 -0.0493 0.2669 -0.2282 0.5146 0.1002', 
        '1.10 -0.0778 0.2565 -0.2036 0.5059 0.1018', 
        '1.15 -0.1029 0.2467 -0.1810 0.4974 0.1034', 
        '1.20 -0.1253 0.2374 -0.1603 0.4892 0.1050', 
        '1.25 -0.1452 0.2286 -0.1413 0.4812 0.1067', 
        '1.30 -0.1629 0.2203 -0.1238 0.4735 0.1083', 
        '1.35 -0.1786 0.2123 -0.1077 0.4660 0.1100', 
        '1.40 -0.1927 0.2048 -0.0929 0.4588 0.1116',
        '1.45 -0.2053 0.1976 -0.0792 0.4518 0.1133', 
        '1.50 -0.2165 0.1908 -0.0666 0.4451 0.1149',
        '1.55 -0.2265 0.1843 -0.0549 0.4386 0.1165', 
        '1.60 -0.2355 0.1782 -0.0442 0.4323 0.1181',
        '1.65 -0.2436 0.1723 -0.0342 0.4262 0.1196',
        '1.70 -0.2508 0.1667 -0.0251 0.4204 0.1211', 
        '1.75 -0.2573 0.1615 -0.0166 0.4148 0.1226', 
        '1.80 -0.2632 0.1565 -0.0088 0.4094 0.1241', 
        '1.85 -0.2684 0.1517 -0.0015 0.4042 0.1256', 
        '1.90 -0.2731 0.1472 0.0052 0.3992 0.1270', 
        '1.95 -0.2774 0.1430 0.0114 0.3944 0.1284', 
        '2.00 -0.2812 0.1390 0.0171 0.3898 0.1297', 
        '2.05 -0.2847 0.1352 0.0223 0.3853 0.1310', 
        '2.10 -0.2879 0.1316 0.0272 0.3811 0.1323', 
        '2.15 -0.2908 0.1282 0.0317 0.3769 0.1335',
        '2.20 -0.2934 0.1251 0.0359 0.3730 0.1347', 
        '2.25 -0.2958 0.1221 0.0397 0.3692 0.1359',
        '2.30 -0.2980 0.1193 0.0432 0.3655 0.1370', 
        '2.35 -0.3000 0.1167 0.0465 0.3620 0.1381',
        '2.40 -0.3018 0.1142 0.0495 0.3586 0.1392',
        '2.45 -0.3035 0.1119 0.0523 0.3553 0.1402',
        '2.50 -0.3051 0.1098 0.0549 0.3521 0.1412',
        '2.55 -0.3066 0.1078 0.0572 0.3491 0.1422',
        '2.60 -0.3079 0.1059 0.0594 0.3461 0.1432',
        '2.65 -0.3092 0.1042 0.0614 0.3433 0.1441',
        '2.70 -0.3104 0.1026 0.0632 0.3406 0.1450',
        '2.75 -0.3115 0.1011 0.0649 0.3379 0.1458',
        '2.80 -0.3125 0.0997 0.0665 0.3354 0.1467',
        '2.85 -0.3135 0.0984 0.0679 0.3329 0.1475']

RG = []
BaseG = []
Z0G =   []
Z1G =   []
Z0Z1G = []
X0X1G = []
Y0Y1G = []

for line in data:
    rv, bv, v0, v1, v01, w01 = line.split(' ', 7)
    RG.append(float(rv))
    BaseG.append(float(bv))
    Z1G.append(float(v0))
    Z0G.append(float(v1))
    Z0Z1G.append(float(v01))
    X0X1G.append(float(w01))
    Y0Y1G.append(float(w01))
    
#
# LBNL/UC Berkeley data
#

RL = [float(x) for x in '0.05 0.10 0.15 0.20 0.25 0.30 0.35 0.40 0.45 0.50 0.55 0.65 0.75 0.85 0.95 1.05 1.15 1.25 1.35 1.45 1.55 1.65 1.75 1.85 1.95 2.05 2.15 2.25 2.35 2.45 2.55 2.65 2.75 2.85 2.95 3.05 3.15 3.25 3.35 3.45 3.55 3.65 3.75 3.85 3.95'.split(' ')]
BaseL = [float(x) for x in '1.00777E+01 4.75665E+00 2.94817E+00 2.01153E+00 1.42283E+00 1.01018E+00 7.01273E-01 4.60364E-01 2.67547E-01 1.10647E-01 -1.83734E-02 -2.13932E-01 -3.49833E-01 -4.45424E-01 -5.13548E-01 -5.62600E-01 -5.97973E-01 -6.23223E-01 -6.40837E-01 -6.52661E-01 -6.60117E-01 -6.64309E-01 -6.66092E-01 -6.66126E-01 -6.64916E-01 -6.62844E-01 -6.60199E-01 -6.57196E-01 -6.53992E-01 -6.50702E-01 -6.47408E-01 -6.44165E-01 -6.41011E-01 -6.37971E-01 -6.35058E-01 -6.32279E-01 -6.29635E-01 -6.27126E-01 -6.24746E-01 -6.22491E-01 -6.20353E-01 -6.18325E-01 -6.16401E-01 -6.14575E-01 -6.12839E-01'.split(' ')]
Z0L = [float(x) for x in '-1.05533E+00 -1.02731E+00 -9.84234E-01 -9.30489E-01 -8.70646E-01 -8.08649E-01 -7.47416E-01 -6.88819E-01 -6.33890E-01 -5.83080E-01 -5.36489E-01 -4.55433E-01 -3.88748E-01 -3.33747E-01 -2.87796E-01 -2.48783E-01 -2.15234E-01 -1.86173E-01 -1.60926E-01 -1.38977E-01 -1.19894E-01 -1.03305E-01 -8.88906E-02 -7.63712E-02 -6.55065E-02 -5.60866E-02 -4.79275E-02 -4.08672E-02 -3.47636E-02 -2.94924E-02 -2.49459E-02 -2.10309E-02 -1.76672E-02 -1.47853E-02 -1.23246E-02 -1.02318E-02 -8.45958E-03 -6.96585E-03 -5.71280E-03 -4.66670E-03 -3.79743E-03 -3.07840E-03 -2.48625E-03 -2.00063E-03 -1.60393E-03'.split(' ')]
X0X1L = [float(x) for x in '1.55708E-01 1.56170E-01 1.56930E-01 1.57973E-01 1.59277E-01 1.60818E-01 1.62573E-01 1.64515E-01 1.66621E-01 1.68870E-01 1.71244E-01 1.76318E-01 1.81771E-01 1.87562E-01 1.93650E-01 1.99984E-01 2.06495E-01 2.13102E-01 2.19727E-01 2.26294E-01 2.32740E-01 2.39014E-01 2.45075E-01 2.50896E-01 2.56458E-01 2.61750E-01 2.66768E-01 2.71512E-01 2.75986E-01 2.80199E-01 2.84160E-01 2.87881E-01 2.91376E-01 2.94658E-01 2.97741E-01 3.00638E-01 3.03362E-01 3.05927E-01 3.08344E-01 3.10625E-01 3.12780E-01 3.14819E-01 3.16750E-01 3.18581E-01 3.20320E-01'.split(' ')]
Z1L = [float(x) for x in '-1.05533E+00 -1.02731E+00 -9.84234E-01 -9.30489E-01 -8.70646E-01 -8.08649E-01 -7.47416E-01 -6.88819E-01 -6.33890E-01 -5.83080E-01 -5.36489E-01 -4.55433E-01 -3.88748E-01 -3.33747E-01 -2.87796E-01 -2.48783E-01 -2.15234E-01 -1.86173E-01 -1.60926E-01 -1.38977E-01 -1.19894E-01 -1.03305E-01 -8.88906E-02 -7.63712E-02 -6.55065E-02 -5.60866E-02 -4.79275E-02 -4.08672E-02 -3.47636E-02 -2.94924E-02 -2.49459E-02 -2.10309E-02 -1.76672E-02 -1.47853E-02 -1.23246E-02 -1.02317E-02 -8.45958E-03 -6.96585E-03 -5.71280E-03 -4.66670E-03 -3.79743E-03 -3.07840E-03 -2.48625E-03 -2.00062E-03 -1.60392E-03'.split(' ')]
Z0Z1L = [float(x) for x in '1.39333E-02 1.38667E-02 1.37610E-02 1.36238E-02 1.34635E-02 1.32880E-02 1.31036E-02 1.29140E-02 1.27192E-02 1.25165E-02 1.23003E-02 1.18019E-02 1.11772E-02 1.04061E-02 9.50345E-03 8.50998E-03 7.47722E-03 6.45563E-03 5.48623E-03 4.59760E-03 3.80558E-03 3.11545E-03 2.52480E-03 2.02647E-03 1.61100E-03 1.26812E-03 9.88000E-04 7.61425E-04 5.80225E-04 4.36875E-04 3.25025E-04 2.38800E-04 1.73300E-04 1.24200E-04 8.78750E-05 6.14500E-05 4.24250E-05 2.89500E-05 1.95500E-05 1.30500E-05 8.57500E-06 5.60000E-06 3.60000E-06 2.27500E-06 1.42500E-06'.split(' ')]

# %%
# Considering a clean Python 3.7 environment, install:
# python -m pip install numpy jupyter matplot
# python -m pip install openfermion openfermionpsi4
# python -m pip install pytest deepdiff pint
#
# Compile latest psi4 and install
# export PYTHONPATH=<location of psi4>/lib:$PYTHONPATH
# export PSI_SCRATCH=$PWD
#

import psi4
import numpy 
from numpy import array
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator

molecule =  MolecularData(geometry=[("H", (0, 0, 0)), ("H", (0, 0, 2.05))], basis='sto-3g', multiplicity=1,
                          description=str(round(5.6, 4)), filename="", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")

#
# Shortest bond length with Psi4 is 0.1 Angstrom
#

mol = psi4.geometry("""
H 0 0 0.0
H 0 0 2.05
units ang
symmetry c1""")
mol.set_multiplicity(1)
mol.set_molecular_charge(0)

# Psi4 does not have sto-6g. You can download the file from basissetexchange.org and store
# it in your local directory. Set PSIPATH to directory where the file is.

hf_energy, hf_wavefunction = psi4.energy('hf/sto-3g', molecule=mol, return_wfn=True)

molecule.hf_energy = hf_energy
molecule.nuclear_repulsion = mol.nuclear_repulsion_energy()
molecule.canonical_orbitals = numpy.asarray(hf_wavefunction.Ca())
molecule.n_orbitals = molecule.canonical_orbitals.shape[0]
molecule.n_qubits = 2 * molecule.n_orbitals
molecule.orbital_energies = numpy.asarray(hf_wavefunction.epsilon_a())
molecule.fock_matrix = numpy.asarray(hf_wavefunction.Fa())

mints = psi4.core.MintsHelper(hf_wavefunction.basisset())
molecule.one_body_integrals = general_basis_change(
    numpy.asarray(mints.ao_kinetic()), molecule.canonical_orbitals, [0,0])
molecule.one_body_integrals += general_basis_change(
    numpy.asarray(mints.ao_potential()), molecule.canonical_orbitals, [0,0])
two_body_integrals = numpy.asarray(mints.ao_eri())
two_body_integrals.reshape((molecule.n_orbitals, molecule.n_orbitals,
                                    molecule.n_orbitals, molecule.n_orbitals))
two_body_integrals = numpy.einsum('psqr', two_body_integrals)
two_body_integrals = general_basis_change(
    two_body_integrals, molecule.canonical_orbitals, [0,0,0,0])

molecule.two_body_integrals = two_body_integrals
molecule.save()

# THE JOURNAL OF CHEMICAL PHYSICS 137, 224109 (2012)
# arXiv:1001.3855
# Both do not account for nuclear repulsion of 0.7137758743754461
# subtracting that from OpenFermion results you get the same answer as them

occupied_index = range(molecule.n_electrons//2 - 1)
active_index = range(molecule.n_electrons//2 - 1, molecule.n_electrons//2 + 1)

print(molecule.orbital_energies, '\n', molecule.n_electrons//2, 'Occupied orbitals', '\n')
fermion_hamiltonian = get_fermion_operator(molecule.get_molecular_hamiltonian(occupied_indices=occupied_index, 
                                                                              active_indices=active_index))
print(fermion_hamiltonian)
# Out:
# [-0.26285204  0.10107717]
#  1 Occupied orbitals
#
# 0.25813522471707323 [] +
# -0.7691479247173999 [0^ 0] +
# 0.253205708250911 [0^ 0^ 0 0] +
# 0.13087518740913562 [0^ 0^ 2 2] +
# 0.253205708250911 [0^ 1^ 1 0] +
# 0.13087518740913562 [0^ 1^ 3 2] +
# 0.13087518740913562 [0^ 2^ 0 2] +
# 0.25803176236128555 [0^ 2^ 2 0] +
# 0.13087518740913562 [0^ 3^ 1 2] +
# 0.25803176236128555 [0^ 3^ 3 0] +
# 0.253205708250911 [1^ 0^ 0 1] +
# 0.13087518740913562 [1^ 0^ 2 3] +
# -0.7691479247173999 [1^ 1] +
# 0.253205708250911 [1^ 1^ 1 1] +
# 0.13087518740913562 [1^ 1^ 3 3] +
# 0.13087518740913562 [1^ 2^ 0 3] +
# 0.25803176236128555 [1^ 2^ 2 1] +
# 0.13087518740913562 [1^ 3^ 1 3] +
# 0.25803176236128555 [1^ 3^ 3 1] +
# 0.2580317623612856 [2^ 0^ 0 2] +
# 0.13087518740913565 [2^ 0^ 2 0] +
# 0.2580317623612856 [2^ 1^ 1 2] +
# 0.13087518740913565 [2^ 1^ 3 0] +
# -0.6691630427263378 [2^ 2] +
# 0.13087518740913565 [2^ 2^ 0 0] +
# 0.2653940516020662 [2^ 2^ 2 2] +
# 0.13087518740913565 [2^ 3^ 1 0] +
# ...

# %%
def clean_qubits(qubit_operator, removables):
    new_qubit_operator = QubitOperator()
    for term, coefficient in qubit_operator.terms.items():
        term = list(term)
        for item in reversed(range(len(term))):
            if term[item][0] in removables and term[item][1] == 'Z':
                del term[item]
        new_qubit_operator += QubitOperator(tuple(term), coefficient)
    return (new_qubit_operator) 

def reduce_jw(qubit_operator):
    g0 = 0
    g1 = 0
    g2 = 0
    g3 = 0
    for term, coefficient in qubit_operator.terms.items():
        if term == ():
            g0 += coefficient
        if term == ((0, 'Z'), (2, 'Z')):
            g0 -= 2*coefficient
        if term == ((1, 'Z'), (2, 'Z')):
            g1 -= 2*coefficient
        if term == ((0, 'Y'), (1, 'X'), (2, 'X'), (3, 'Y')):
            g2 += 4*coefficient
        if term == ((2, 'Z'), (3, 'Z')):
            g1 += coefficient
        if term == ((0, 'Z'), (1, 'Z')):
            g1 += coefficient
        if term == ((2, 'Z'),):
            g3 += coefficient
        if term == ((0, 'Z'),):
            g3 -= coefficient
    print(g0,g1,g2,g3)
    new_qubit_operator = QubitOperator((), g0)
    new_qubit_operator += QubitOperator(((0, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((1, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((0, 'X'), (1, 'X')), g2)
    new_qubit_operator += QubitOperator(((0, 'Z'), (1, 'Z')), g1)
    return new_qubit_operator

print('Fermion Hamiltonian in Second Quantized Form')
print(fermion_hamiltonian)

#print('\nBravyi-Kitaev')
#print(bravyi_kitaev(fermion_hamiltonian))
#print('\nBravyi-Kitaev with 1 and 3 removed')
#print(clean_qubits(bravyi_kitaev(fermion_hamiltonian), [1,3]))
#print('Google', 'R', RG[6], '1', BaseG[6], 'Z0', Z0G[6], 'Z1', Z1G[6], 'Z0Z1', Z0Z1G[6], 'X0X1', X0X1G[6], 'Y0Y1', Y0Y1G[6])
#print('LBNL  ', 'R', RL[9], '1', BaseL[9], 'Z0', Z0L[9], 'Z1', Z1L[9], 'Z0Z1', Z0Z1L[9], 'X0X1', X0X1L[9])

print('\nJordan-Wigner')
print(jordan_wigner(fermion_hamiltonian))
print('\nJordan-Wigner reduced')
print(reduce_jw(jordan_wigner(fermion_hamiltonian)))
#print('Google', 'R', RG[6], '1', BaseG[6], 'Z0', Z0G[6], 'Z1', Z1G[6], 'Z0Z1', Z0Z1G[6], 'X0X1', X0X1G[6], 'Y0Y1', Y0Y1G[6])
print('LBNL  ', 'R', RL[25], '1', BaseL[25], 'Z0', Z0L[25], 'Z1', Z1L[25], 'Z0Z1', Z0Z1L[25], 'X0X1', X0X1L[25])

#print('\nBravyi-Kitaev Tree')
#print(bravyi_kitaev_tree(fermion_hamiltonian))
#print('\nBravyi-Kitaev Tree with 1 and 3 removed')
#print(clean_qubits(bravyi_kitaev_tree(fermion_hamiltonian), [1,3]))
#print('Google', 'R', RG[6], '1', BaseG[6], 'Z0', Z0G[6], 'Z1', Z1G[6], 'Z0Z1', Z0Z1G[6], 'X0X1', X0X1G[6], 'Y0Y1', Y0Y1G[6])
#print('LBNL  ', 'R', RL[9], '1', BaseL[9], 'Z0', Z0L[9], 'Z1', Z1L[9], 'Z0Z1', Z0Z1L[9], 'X0X1', X0X1L[9])
# Out:
# Fermion Hamiltonian in Second Quantized Form
# 0.25813522471707323 [] +
# -0.7691479247173999 [0^ 0] +
# 0.253205708250911 [0^ 0^ 0 0] +
# 0.13087518740913562 [0^ 0^ 2 2] +
# 0.253205708250911 [0^ 1^ 1 0] +
# 0.13087518740913562 [0^ 1^ 3 2] +
# 0.13087518740913562 [0^ 2^ 0 2] +
# 0.25803176236128555 [0^ 2^ 2 0] +
# 0.13087518740913562 [0^ 3^ 1 2] +
# 0.25803176236128555 [0^ 3^ 3 0] +
# 0.253205708250911 [1^ 0^ 0 1] +
# 0.13087518740913562 [1^ 0^ 2 3] +
# -0.7691479247173999 [1^ 1] +
# 0.253205708250911 [1^ 1^ 1 1] +
# 0.13087518740913562 [1^ 1^ 3 3] +
# 0.13087518740913562 [1^ 2^ 0 3] +
# 0.25803176236128555 [1^ 2^ 2 1] +
# 0.13087518740913562 [1^ 3^ 1 3] +
# 0.25803176236128555 [1^ 3^ 3 1] +
# 0.2580317623612856 [2^ 0^ 0 2] +
# 0.13087518740913565 [2^ 0^ 2 0] +
# 0.2580317623612856 [2^ 1^ 1 2] +
# 0.13087518740913565 [2^ 1^ 3 0] +
# -0.6691630427263378 [2^ 2] +
# 0.13087518740913565 [2^ 2^ 0 0] +
# 0.2653940516020662 [2^ 2^ 2 2] +
# 0.13087518740913565 [2^ 3^ 1 0] +
# ...

# %% [markdown]
# # Li<sub>2</sub> with STO-3G LBL Style

# %%
import psi4
import numpy 
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator, InteractionOperator
import yaml as yml
from yaml import SafeLoader as Loader
import os

def reduce_jw(qubit_operator):
    g0 = 0
    g1 = 0
    g2 = 0
    g3 = 0
    for term, coefficient in qubit_operator.terms.items():
        if term == ():
            g0 += coefficient
        if term == ((0, 'Z'), (2, 'Z')):
            g0 -= 2*coefficient
        if term == ((1, 'Z'), (2, 'Z')):
            g1 -= 2*coefficient
        if term == ((0, 'Y'), (1, 'X'), (2, 'X'), (3, 'Y')):
            g2 += 4*coefficient
        if term == ((2, 'Z'), (3, 'Z')):
            g1 += coefficient
        if term == ((0, 'Z'), (1, 'Z')):
            g1 += coefficient
        if term == ((2, 'Z'),):
            g3 += coefficient
        if term == ((0, 'Z'),):
            g3 -= coefficient
    new_qubit_operator = QubitOperator((), g0)
    new_qubit_operator += QubitOperator(((0, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((1, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((0, 'X'), (1, 'X')), g2)
    new_qubit_operator += QubitOperator(((0, 'Z'), (1, 'Z')), g1)
    return new_qubit_operator

#################### WALK ROOT DIR ############################
root_dir = '/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS'
data_file_list = []

for dirName, subdirList, fileList in os.walk(root_dir):
    print('Found directory: %s' % dirName)
    for fname in sorted(fileList):
        if fname.endswith('.yaml'):
            data_file_list.append(fname)

#Erasing list to check with H2
#data_file_list = ['H2.yaml']
###############################################################
R = []
Base = []
Z0 = []
Z1 = []
Z0Z1 = []
X0X1 = []


#Looping over all of the yaml files in a particular directory and saving the energies from VQE and Exact
for ind, file in enumerate(data_file_list):
    

    NW_data_file = str(os.path.join(root_dir,file))
    #NW_data_file = data_file_list[0]
    doc = open(NW_data_file, 'r')
    data = yml.load(doc, Loader)

    
    #Import all the data from a yaml file
    dist = 2 * data['integral_sets'][0]['geometry']['atoms'][1]['coords'][2]
    R.append(round(dist,3))
    moldata =  MolecularData(geometry=[('Li', (0, 0, 0)), ('Li', (0, 0, round(dist,3)))], basis='sto-3g', multiplicity=1,
                          description=str(dist), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
    string = 'Li' + " 0 0 0.0 \n" + 'Li' + " 0 0 " + str(round(dist,3)) + "\n" + "units ang \n" + "symmetry c1"
    mol = psi4.geometry(string)
    mol.set_multiplicity(1)
    psi4.set_options({'frozen_docc': [2], 'frozen_uocc' : [0]})
    mol.set_molecular_charge(0)

    hf_energy, hf_wavefunction = psi4.energy('hf/sto-3g', molecule=mol, return_wfn=True)
    print(round(dist,3),hf_energy)

    moldata.hf_energy = hf_energy
    moldata.nuclear_repulsion = mol.nuclear_repulsion_energy()
    moldata.canonical_orbitals = numpy.asarray(hf_wavefunction.Ca())
    moldata.n_orbitals = moldata.canonical_orbitals.shape[0]
    moldata.n_qubits = 2 * moldata.n_orbitals
    moldata.orbital_energies = numpy.asarray(hf_wavefunction.epsilon_a())
    moldata.fock_matrix = numpy.asarray(hf_wavefunction.Fa())

    mints = psi4.core.MintsHelper(hf_wavefunction.basisset())
    moldata.one_body_integrals = general_basis_change(
        numpy.asarray(mints.ao_kinetic()), moldata.canonical_orbitals, [0,0])
    moldata.one_body_integrals += general_basis_change(
        numpy.asarray(mints.ao_potential()), moldata.canonical_orbitals, [0,0])
    two_body_integrals = numpy.asarray(mints.ao_eri())
    two_body_integrals.reshape((moldata.n_orbitals, moldata.n_orbitals,
                              moldata.n_orbitals, moldata.n_orbitals))
    two_body_integrals = numpy.einsum('psqr', two_body_integrals)
    two_body_integrals = general_basis_change(two_body_integrals, moldata.canonical_orbitals, [0,0,0,0])

    moldata.two_body_integrals = two_body_integrals
    moldata.save()

    occupied_index = range(moldata.n_electrons//2 - 1)
    active_index = range(moldata.n_electrons//2 - 1, moldata.n_electrons//2 + 1)

    fermion_hamiltonian = get_fermion_operator(moldata.get_molecular_hamiltonian(
            occupied_indices=occupied_index, active_indices=active_index))
    hamiltonian = reduce_jw(jordan_wigner(fermion_hamiltonian))
    for term, coefficient in hamiltonian.terms.items():
        if term == ():
            Base.append(coefficient.real)
        if term == ((0, 'Z'), (1, 'Z')):
            Z0Z1.append(coefficient.real)
        if term == ((0, 'X'), (1, 'X')):
            X0X1.append(coefficient.real)
        if term == ((1, 'Z'),):
            Z1.append(coefficient.real)
        if term == ((0, 'Z'),):
            Z0.append(coefficient.real)
                
print(' R   Base     Z0      Z1      Z0Z1     X0X1')
for rv, bv, z0v, z1v, z0z1v, x0x1v,  in zip(R,Base,Z0,Z1,Z0Z1,X0X1):
    print(rv, bv, z0v, z1v, z0z1v, x0x1v )
# Out:
# Found directory: /Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS
# 2.138 -14.621690942812041
# 2.272 -14.629719961363822
# 2.406 -14.634933469678895
# 2.539 -14.637825678487165
# 2.673 -14.638882063543818
# 2.807 -14.63844824150032
# 2.94 -14.636850485143713
# 3.074 -14.634317887850738
# 3.208 -14.631066850903524
# 3.341 -14.627298133017966
# 4.01 -14.60427069855809
# 4.678 -14.580846375550838
# 5.346 -14.561136733697605
# 6.683 -14.536071387229569
# 13.365 -14.509845151144276
#  R   Base     Z0      Z1      Z0Z1     X0X1
# 2.138 -14.531892158752457 -0.05295488116001604 -0.05295488116001604 0.016269474578402526 0.04186707287929487
# 2.272 -14.541206996361518 -0.05274545495820065 -0.05274545495820065 0.01713576774121276 0.040966803836769664
# 2.406 -14.548292259643004 -0.052069943676183436 -0.052069943676183436 0.017655981104911136 0.040626421095287475
# ...

# %% [markdown]
# # Li<sub>2</sub> with STO-6G LBL Style

# %%
import psi4
import numpy 
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator, InteractionOperator
import yaml as yml
from yaml import SafeLoader as Loader
import os

def reduce_jw(qubit_operator):
    g0 = 0
    g1 = 0
    g2 = 0
    g3 = 0
    for term, coefficient in qubit_operator.terms.items():
        if term == ():
            g0 += coefficient
        if term == ((0, 'Z'), (2, 'Z')):
            g0 -= 2*coefficient
        if term == ((1, 'Z'), (2, 'Z')):
            g1 -= 2*coefficient
        if term == ((0, 'Y'), (1, 'X'), (2, 'X'), (3, 'Y')):
            g2 += 4*coefficient
        if term == ((2, 'Z'), (3, 'Z')):
            g1 += coefficient
        if term == ((0, 'Z'), (1, 'Z')):
            g1 += coefficient
        if term == ((2, 'Z'),):
            g3 += coefficient
        if term == ((0, 'Z'),):
            g3 -= coefficient
    new_qubit_operator = QubitOperator((), g0)
    new_qubit_operator += QubitOperator(((0, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((1, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((0, 'X'), (1, 'X')), g2)
    new_qubit_operator += QubitOperator(((0, 'Z'), (1, 'Z')), g1)
    return new_qubit_operator

#################### WALK ROOT DIR ############################
root_dir = '/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS'
data_file_list = []

for dirName, subdirList, fileList in os.walk(root_dir):
    print('Found directory: %s' % dirName)
    for fname in sorted(fileList):
        if fname.endswith('.yaml'):
            data_file_list.append(fname)

#Erasing list to check with H2
#data_file_list = ['H2.yaml']
###############################################################
R = []
Base = []
Z0 = []
Z1 = []
Z0Z1 = []
X0X1 = []


#Looping over all of the yaml files in a particular directory and saving the energies from VQE and Exact
for ind, file in enumerate(data_file_list):
    

    NW_data_file = str(os.path.join(root_dir,file))
    #NW_data_file = data_file_list[0]
    doc = open(NW_data_file, 'r')
    data = yml.load(doc, Loader)

    
    #Import all the data from a yaml file
    dist = 2 * data['integral_sets'][0]['geometry']['atoms'][1]['coords'][2]
    R.append(round(dist,3))
    moldata =  MolecularData(geometry=[('Li', (0, 0, 0)), ('Li', (0, 0, round(dist,3)))], basis='sto-6g', multiplicity=1,
                          description=str(dist), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
    string = 'Li' + " 0 0 0.0 \n" + 'Li' + " 0 0 " + str(round(dist,3)) + "\n" + "units ang \n" + "symmetry c1"
    mol = psi4.geometry(string)
    mol.set_multiplicity(1)
    psi4.set_options({'frozen_docc': [2], 'frozen_uocc' : [0]})
    mol.set_molecular_charge(0)

    hf_energy, hf_wavefunction = psi4.energy('hf/sto-6g', molecule=mol, return_wfn=True)
    print(round(dist,3),hf_energy)

    moldata.hf_energy = hf_energy
    moldata.nuclear_repulsion = mol.nuclear_repulsion_energy()
    moldata.canonical_orbitals = numpy.asarray(hf_wavefunction.Ca())
    moldata.n_orbitals = moldata.canonical_orbitals.shape[0]
    moldata.n_qubits = 2 * moldata.n_orbitals
    moldata.orbital_energies = numpy.asarray(hf_wavefunction.epsilon_a())
    moldata.fock_matrix = numpy.asarray(hf_wavefunction.Fa())

    mints = psi4.core.MintsHelper(hf_wavefunction.basisset())
    moldata.one_body_integrals = general_basis_change(
        numpy.asarray(mints.ao_kinetic()), moldata.canonical_orbitals, [0,0])
    moldata.one_body_integrals += general_basis_change(
        numpy.asarray(mints.ao_potential()), moldata.canonical_orbitals, [0,0])
    two_body_integrals = numpy.asarray(mints.ao_eri())
    two_body_integrals.reshape((moldata.n_orbitals, moldata.n_orbitals,
                              moldata.n_orbitals, moldata.n_orbitals))
    two_body_integrals = numpy.einsum('psqr', two_body_integrals)
    two_body_integrals = general_basis_change(two_body_integrals, moldata.canonical_orbitals, [0,0,0,0])

    moldata.two_body_integrals = two_body_integrals
    moldata.save()

    occupied_index = range(moldata.n_electrons//2 - 1)
    active_index = range(moldata.n_electrons//2 - 1, moldata.n_electrons//2 + 1)

    fermion_hamiltonian = get_fermion_operator(moldata.get_molecular_hamiltonian(
            occupied_indices=occupied_index, active_indices=active_index))
    hamiltonian = reduce_jw(jordan_wigner(fermion_hamiltonian))
    for term, coefficient in hamiltonian.terms.items():
        if term == ():
            Base.append(coefficient.real)
        if term == ((0, 'Z'), (1, 'Z')):
            Z0Z1.append(coefficient.real)
        if term == ((0, 'X'), (1, 'X')):
            X0X1.append(coefficient.real)
        if term == ((1, 'Z'),):
            Z1.append(coefficient.real)
        if term == ((0, 'Z'),):
            Z0.append(coefficient.real)
                
print(' R   Base     Z0      Z1      Z0Z1     X0X1')
for rv, bv, z0v, z1v, z0z1v, x0x1v,  in zip(R,Base,Z0,Z1,Z0Z1,X0X1):
    print(rv, bv, z0v, z1v, z0z1v, x0x1v )
# Out:
# Found directory: /Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS
# 2.138 -14.792316474995795
# 2.272 -14.800131345026383
# 2.406 -14.805170984582116
# 2.539 -14.80793166412926
# 2.673 -14.808892669625958
# 2.807 -14.808394230119555
# 2.94 -14.806755621635462
# 3.074 -14.804198067436145
# 3.208 -14.800931184994754
# 3.341 -14.797148946261057
# 4.01 -14.773906591803549
# 4.678 -14.749975793557349
# 5.346 -14.729920564791351
# 6.683 -14.704899927029748
# 13.365 -14.678045486141617
#  R   Base     Z0      Z1      Z0Z1     X0X1
# 2.138 -14.701085624867746 -0.054042034589623776 -0.054042034589623776 0.01687377499656901 0.04121621981699959
# 2.272 -14.710246547571034 -0.05375823118579407 -0.05375823118579407 0.017652194924875346 0.04038446988577546
# 2.406 -14.717180682267871 -0.053037015868081724 -0.053037015868081724 0.018104275684987917 0.04010917841066492
# ...

# %% [markdown]
# # Li<sub>2</sub> CC-PVTZ basis with Hartree-Fock virtual from Psi4 - LBL Style

# %%
import psi4
import numpy 
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator, InteractionOperator
import yaml as yml
from yaml import SafeLoader as Loader
import os

def reduce_jw(qubit_operator):
    g0 = 0
    g1 = 0
    g2 = 0
    g3 = 0
    for term, coefficient in qubit_operator.terms.items():
        if term == ():
            g0 += coefficient
        if term == ((0, 'Z'), (2, 'Z')):
            g0 -= 2*coefficient
        if term == ((1, 'Z'), (2, 'Z')):
            g1 -= 2*coefficient
        if term == ((0, 'Y'), (1, 'X'), (2, 'X'), (3, 'Y')):
            g2 += 4*coefficient
        if term == ((2, 'Z'), (3, 'Z')):
            g1 += coefficient
        if term == ((0, 'Z'), (1, 'Z')):
            g1 += coefficient
        if term == ((2, 'Z'),):
            g3 += coefficient
        if term == ((0, 'Z'),):
            g3 -= coefficient
    new_qubit_operator = QubitOperator((), g0)
    new_qubit_operator += QubitOperator(((0, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((1, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((0, 'X'), (1, 'X')), g2)
    new_qubit_operator += QubitOperator(((0, 'Z'), (1, 'Z')), g1)
    return new_qubit_operator

#################### WALK ROOT DIR ############################
root_dir = '/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS'
data_file_list = []

for dirName, subdirList, fileList in os.walk(root_dir):
    print('Found directory: %s' % dirName)
    for fname in sorted(fileList):
        if fname.endswith('.yaml'):
            data_file_list.append(fname)

#Erasing list to check with H2
#data_file_list = ['H2.yaml']
###############################################################
R = []
Base = []
Z0 = []
Z1 = []
Z0Z1 = []
X0X1 = []


#Looping over all of the yaml files in a particular directory and saving the energies from VQE and Exact
for ind, file in enumerate(data_file_list):
    

    NW_data_file = str(os.path.join(root_dir,file))
    #NW_data_file = data_file_list[0]
    doc = open(NW_data_file, 'r')
    data = yml.load(doc, Loader)

    
    #Import all the data from a yaml file
    dist = 2 * data['integral_sets'][0]['geometry']['atoms'][1]['coords'][2]
    R.append(round(dist,3))
    moldata =  MolecularData(geometry=[('Li', (0, 0, 0)), ('Li', (0, 0, round(dist,3)))], basis='cc-pvtz', multiplicity=1,
                          description=str(dist), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
    string = 'Li' + " 0 0 0.0 \n" + 'Li' + " 0 0 " + str(round(dist,3)) + "\n" + "units ang \n" + "symmetry c1"
    mol = psi4.geometry(string)
    mol.set_multiplicity(1)
    psi4.set_options({'frozen_docc': [2], 'frozen_uocc' : [56]})
    mol.set_molecular_charge(0)

    hf_energy, hf_wavefunction = psi4.energy('hf/cc-pvtz', molecule=mol, return_wfn=True)
    print(round(dist,3),hf_energy)

    moldata.hf_energy = hf_energy
    moldata.nuclear_repulsion = mol.nuclear_repulsion_energy()
    moldata.canonical_orbitals = numpy.asarray(hf_wavefunction.Ca())
    moldata.n_orbitals = moldata.canonical_orbitals.shape[0]
    moldata.n_qubits = 2 * moldata.n_orbitals
    moldata.orbital_energies = numpy.asarray(hf_wavefunction.epsilon_a())
    moldata.fock_matrix = numpy.asarray(hf_wavefunction.Fa())

    mints = psi4.core.MintsHelper(hf_wavefunction.basisset())
    moldata.one_body_integrals = general_basis_change(
        numpy.asarray(mints.ao_kinetic()), moldata.canonical_orbitals, [0,0])
    moldata.one_body_integrals += general_basis_change(
        numpy.asarray(mints.ao_potential()), moldata.canonical_orbitals, [0,0])
    two_body_integrals = numpy.asarray(mints.ao_eri())
    two_body_integrals.reshape((moldata.n_orbitals, moldata.n_orbitals,
                              moldata.n_orbitals, moldata.n_orbitals))
    two_body_integrals = numpy.einsum('psqr', two_body_integrals)
    two_body_integrals = general_basis_change(two_body_integrals, moldata.canonical_orbitals, [0,0,0,0])

    moldata.two_body_integrals = two_body_integrals
    moldata.save()

    occupied_index = range(moldata.n_electrons//2 - 1)
    active_index = range(moldata.n_electrons//2 - 1, moldata.n_electrons//2 + 1)

    fermion_hamiltonian = get_fermion_operator(moldata.get_molecular_hamiltonian(
            occupied_indices=occupied_index, active_indices=active_index))
    hamiltonian = reduce_jw(jordan_wigner(fermion_hamiltonian))
    for term, coefficient in hamiltonian.terms.items():
        if term == ():
            Base.append(coefficient.real)
        if term == ((0, 'Z'), (1, 'Z')):
            Z0Z1.append(coefficient.real)
        if term == ((0, 'X'), (1, 'X')):
            X0X1.append(coefficient.real)
        if term == ((1, 'Z'),):
            Z1.append(coefficient.real)
        if term == ((0, 'Z'),):
            Z0.append(coefficient.real)
                
print(' R   Base     Z0      Z1      Z0Z1     X0X1')
for rv, bv, z0v, z1v, z0z1v, x0x1v,  in zip(R,Base,Z0,Z1,Z0Z1,X0X1):
    print(rv, bv, z0v, z1v, z0z1v, x0x1v )
# Out:
# Found directory: /Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS
# 2.138 -14.854274331265593
# 2.272 -14.861725702098969
# 2.406 -14.86674472598844
# 2.539 -14.869800497620274
# 2.673 -14.871345493939355
# 2.807 -14.871686249478769
# 2.94 -14.871102330127664
# 3.074 -14.869802424471224
# 3.208 -14.867962672345042
# 3.341 -14.865740111440537
# 4.01 -14.851696144979902
# 4.678 -14.837162719281915
# 5.346 -14.824410024685234
# 6.683 -14.805393024690833
# 13.365 -14.77496932324122
#  R   Base     Z0      Z1      Z0Z1     X0X1
# 2.138 -14.750626819131963 -0.06370161449952645 -0.06370161449952645 0.023759184865877747 0.01499878453967138
# 2.272 -14.761286830734598 -0.06198096380307211 -0.06198096380307211 0.023526612922666425 0.015347337298463179
# 2.406 -14.770009520271419 -0.05988423967402178 -0.05988423967402178 0.023036920936254972 0.01591557651831613
# ...

# %% [markdown]
# # Downfolded Virtual Space from NW Chem

# %% [markdown]
# ### Functions to convert uploaded yaml data to one-body integrals
# Note: I compared the reduced Hamiltonians for H2 produced by this method with those above. I get the exact same Hamiltonians, so I know the code will work for different molecules. Inconveniantly, OpenFermion uses 'physicist' notation for the molecular Hamiltonian, so I had to switch some indices around with imported data. All is good.

# %%
import numpy as np
def get_spatial_integrals(one_electron,two_electron,n_o):
    one_electron_spatial_integrals = np.zeros((n_o, n_o))
    two_electron_spatial_integrals = np.zeros((n_o, n_o, n_o, n_o))
    # populating a one-e spatial hamiltonian
    for ind, val in enumerate(one_electron):
        # This is because python index starts at 0
        i = int(val[0] - 1)
        j = int(val[1] - 1)
        one_electron_spatial_integrals[i, j] = val[2]
        if i != j:
            one_electron_spatial_integrals[j, i] = val[2]

    # populating a two-electron spatial hamiltonian
    for ind, val in enumerate(two_electron):
        i = int(val[0]-1)
        j = int(val[1]-1)
        k = int(val[2]-1)
        l = int(val[3]-1)
        my_ind = [i,j,k,l]
        
        two_electron_spatial_integrals[i, j, k, l] = val[4]
        if two_electron_spatial_integrals[k, l, i, j] == 0:
            two_electron_spatial_integrals[k, l, i, j] = val[4]
        if two_electron_spatial_integrals[i, j, l, k] == 0:
            two_electron_spatial_integrals[i, j, l, k] = val[4]
        if two_electron_spatial_integrals[l, k, i, j] == 0:
            two_electron_spatial_integrals[l, k, i, j] = val[4]
        if two_electron_spatial_integrals[j, i, k, l] == 0:
            two_electron_spatial_integrals[j, i, k, l] = val[4]
        if two_electron_spatial_integrals[k, l, j, i] == 0:
            two_electron_spatial_integrals[k, l, j, i] = val[4]
        if two_electron_spatial_integrals[j, i, l, k] == 0:
            two_electron_spatial_integrals[j, i, l, k] = val[4]
        if two_electron_spatial_integrals[l, k, j, i] == 0:
            two_electron_spatial_integrals[l, k, j, i] = val[4]

    return one_electron_spatial_integrals, two_electron_spatial_integrals

def trunctate_spatial_integrals(one_electron, two_electron, trunc):
    one_electron = np.where((abs(one_electron) < trunc), 0,one_electron)
    two_electron = np.where((abs(two_electron) < trunc), 0, two_electron)
    return one_electron,two_electron

def convert_to_spin_index(one_electron, two_electron,n_o):
    h1 = np.block([[one_electron, np.zeros((int(n_o), int(n_o)))],
                   [np.zeros((int(n_o), int(n_o))), one_electron]])
    h2 = np.zeros((2 * n_o, 2 * n_o, 2 * n_o, 2 * n_o))
    double_excitations = []
    for i in range(len(two_electron)):
        for j in range(len(two_electron)):
            for k in range(len(two_electron)):
                for l in range(len(two_electron)):
                    h2[i,j, k + n_o, l + n_o] = two_electron[i, j, k, l]
                    h2[i + n_o, j + n_o,k, l] = two_electron[i, j, k, l]
                    if i!=k and j!=l:
                        h2[i,j,k,l] = two_electron[i,j,k,l]
                        h2[i + n_o, j + n_o, k + n_o, l + n_o] = two_electron[i, j, k, l]

    return h1, 0.5*h2

# %%
import psi4
import numpy 
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator, InteractionOperator
import yaml as yml
from yaml import SafeLoader as Loader
import os

def reduce_jw(qubit_operator):
    g0 = 0
    g1 = 0
    g2 = 0
    g3 = 0
    for term, coefficient in qubit_operator.terms.items():
        if term == ():
            g0 += coefficient
        if term == ((0, 'Z'), (2, 'Z')):
            g0 -= 2*coefficient
        if term == ((1, 'Z'), (2, 'Z')):
            g1 -= 2*coefficient
        if term == ((0, 'Y'), (1, 'X'), (2, 'X'), (3, 'Y')):
            g2 += 4*coefficient
        if term == ((2, 'Z'), (3, 'Z')):
            g1 += coefficient
        if term == ((0, 'Z'), (1, 'Z')):
            g1 += coefficient
        if term == ((2, 'Z'),):
            g3 += coefficient
        if term == ((0, 'Z'),):
            g3 -= coefficient
    new_qubit_operator = QubitOperator((), g0)
    new_qubit_operator += QubitOperator(((0, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((1, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((0, 'X'), (1, 'X')), g2)
    new_qubit_operator += QubitOperator(((0, 'Z'), (1, 'Z')), g1)
    return new_qubit_operator


#################### WALK ROOT DIR ############################
root_dir = '/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS'
data_file_list = []

for dirName, subdirList, fileList in os.walk(root_dir):
    print('Found directory: %s' % dirName)
    for fname in sorted(fileList):
        if fname.endswith('.yaml'):
            data_file_list.append(fname)

#Erasing list to check with H2
#data_file_list = ['H2.yaml']
###############################################################
R = []
Base = []
Z0 = []
Z1 = []
Z0Z1 = []
X0X1 = []


#Looping over all of the yaml files in a particular directory and saving the energies from VQE and Exact
for ind, file in enumerate(data_file_list):
    

    NW_data_file = str(os.path.join(root_dir,file))
    #NW_data_file = data_file_list[0]
    doc = open(NW_data_file, 'r')
    data = yml.load(doc, Loader)

    
    #Import all the data from a yaml file
    n_spatial_orbitals = data['integral_sets'][0]['n_orbitals']
    nuclear_repulsion_energy = data['integral_sets'][0]['coulomb_repulsion']['value']
    n_orbitals = 2 * n_spatial_orbitals
    n_particles = data['integral_sets'][0]['n_electrons']
    dist = 2 * data['integral_sets'][0]['geometry']['atoms'][1]['coords'][2]
    R.append(round(dist,3))
    #print('Bond distance is {}'.format(dist))
    n_qubits = n_orbitals

    one_electron_import = data['integral_sets'][0]['hamiltonian']['one_electron_integrals']['values']
    two_electron_import = data['integral_sets'][0]['hamiltonian']['two_electron_integrals']['values']

    #Getting spatial integrals and spin integrals to construct Hamiltonian
    one_electron_spatial_integrals, two_electron_spatial_integrals = get_spatial_integrals(one_electron_import,
                                                                                              two_electron_import,
                                                                                              n_spatial_orbitals)
    one_electron_spatial_integrals, two_electron_spatial_integrals = trunctate_spatial_integrals(
        one_electron_spatial_integrals, two_electron_spatial_integrals, .001)
    ##################change indices because OF uses physicist notation #################################
    two_electron_spatial_integrals = np.einsum('ijkl->iklj', two_electron_spatial_integrals)
    #################### create Hamiltonian with spin orbital #################################
    h1, h2 = convert_to_spin_index(one_electron_spatial_integrals, two_electron_spatial_integrals,
                                                  n_spatial_orbitals)
    #Instantiate my own hamiltonian outside of molecular data class############################
    molecular_hamiltonian = InteractionOperator(nuclear_repulsion_energy, h1, h2)
    fermion_hamiltonian = get_fermion_operator(molecular_hamiltonian)
    jw_op = jordan_wigner(fermion_hamiltonian)
    ############################ Use scheme introduce in previous code to reduce Ham to 2 qubits #######
    print('Reduced Hamiltonian for Li_2 separated by {}'.format(dist))
    hamiltonian = reduce_jw(jw_op)
    #print(hamiltonian, '\n')
    
    
    #
    # Bert's modification to put data into MolecularData object and get fermion hamiltonian based on active indices
    #
    moldata =  MolecularData(geometry=[('Li', (0, 0, 0)), ('Li', (0, 0, dist))], basis='sto-3g', multiplicity=1,
                          description=str(dist), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
    moldata.nuclear_repulsion = nuclear_repulsion_energy
    moldata.n_orbitals = 4
    moldata.n_qubits = 2 * moldata.n_orbitals
    moldata.n_electrons = 6
    moldata.one_body_integrals = one_electron_spatial_integrals
    moldata.two_body_integrals = two_electron_spatial_integrals
    moldata.save()
    occupied_index = range(moldata.n_electrons//2 - 1)
    active_index = range(moldata.n_electrons//2 - 1, moldata.n_electrons//2 + 1)
    fermion_hamiltonian = get_fermion_operator(moldata.get_molecular_hamiltonian(
                          occupied_indices=occupied_index, active_indices=active_index))
    hamiltonian = reduce_jw(jordan_wigner(fermion_hamiltonian))
    print(hamiltonian)
    for term, coefficient in hamiltonian.terms.items():
            #print(term, coefficient)
            if term == ():
                Base.append(coefficient.real)
            if term == ((0, 'Z'), (1, 'Z')):
                Z0Z1.append(coefficient.real)
            if term == ((0, 'X'), (1, 'X')):
                X0X1.append(coefficient.real)
            if term == ((1, 'Z'),):
                Z1.append(coefficient.real)
            if term == ((0, 'Z'),):
                Z0.append(coefficient.real)

                
print(' R   Base     Z0      Z1      Z0Z1     X0X1')
for rv, bv, z0v, z1v, z0z1v, x0x1v,  in zip(R,Base,Z0,Z1,Z0Z1,X0X1):
    print(rv, bv, z0v, z1v, z0z1v, x0x1v )
# Out:
# Found directory: /Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS
# Reduced Hamiltonian for Li_2 separated by 2.1384
# (-14.772026295220545+0j) [] +
# (0.0143743962+0j) [X0 X1] +
# (-0.061499577525+0j) [Z0] +
# (0.024820122575000006+0j) [Z0 Z1] +
# (-0.061499577525+0j) [Z1]
# Reduced Hamiltonian for Li_2 separated by 2.27205
# (-14.782925879575211+0j) [] +
# (0.014786734999999999+0j) [X0 X1] +
# (-0.06026153240000004+0j) [Z0] +
# (0.02404298245+0j) [Z0 Z1] +
# (-0.06026153240000004+0j) [Z1]
# Reduced Hamiltonian for Li_2 separated by 2.4057
# (-14.79177927495715+0j) [] +
# (0.015461414800000002+0j) [X0 X1] +
# (-0.058512747249999955+0j) [Z0] +
# (0.02311693335+0j) [Z0 Z1] +
# (-0.058512747249999955+0j) [Z1]
# Reduced Hamiltonian for Li_2 separated by 2.53935
# (-14.798951959840984+0j) [] +
# (0.0163626598+0j) [X0 X1] +
# (-0.05640950229999992+0j) [Z0] +
# (0.022085402049999994+0j) [Z0 Z1] +
# (-0.05640950229999992+0j) [Z1]
# ...

# %% [markdown]
# # STO-3G Google Style - Frozen Core - 1 Virtual

# %%
import psi4
import numpy 
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator, InteractionOperator
import yaml as yml
from yaml import SafeLoader as Loader
import os

def clean_qubits(qubit_operator, removables):
    new_qubit_operator = QubitOperator()
    for term, coefficient in qubit_operator.terms.items():
        term = list(term)
        for item in reversed(range(len(term))):
            if term[item][0] in removables and term[item][1] == 'Z':
                del term[item]
        new_qubit_operator += QubitOperator(tuple(term), coefficient)
    return (new_qubit_operator) 

def reduce_jw(qubit_operator):
    g0 = 0
    g1 = 0
    g2 = 0
    g3 = 0
    for term, coefficient in qubit_operator.terms.items():
        if term == ():
            g0 += coefficient
        if term == ((0, 'Z'), (2, 'Z')):
            g0 -= 2*coefficient
        if term == ((1, 'Z'), (2, 'Z')):
            g1 -= 2*coefficient
        if term == ((0, 'Y'), (1, 'X'), (2, 'X'), (3, 'Y')):
            g2 += 4*coefficient
        if term == ((2, 'Z'), (3, 'Z')):
            g1 += coefficient
        if term == ((0, 'Z'), (1, 'Z')):
            g1 += coefficient
        if term == ((2, 'Z'),):
            g3 += coefficient
        if term == ((0, 'Z'),):
            g3 -= coefficient
    new_qubit_operator = QubitOperator((), g0)
    new_qubit_operator += QubitOperator(((0, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((1, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((0, 'X'), (1, 'X')), g2)
    new_qubit_operator += QubitOperator(((0, 'Z'), (1, 'Z')), g1)
    return new_qubit_operator

#################### WALK ROOT DIR ############################
root_dir = '/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS'
data_file_list = []

for dirName, subdirList, fileList in os.walk(root_dir):
    print('Found directory: %s' % dirName)
    for fname in sorted(fileList):
        if fname.endswith('.yaml'):
            data_file_list.append(fname)

#Erasing list to check with H2
#data_file_list = ['H2.yaml']
###############################################################
R = []
Base = []
Z0 = []
Z1 = []
Z0Z1 = []
X0X1 = []
Y0Y1 = []


#Looping over all of the yaml files in a particular directory and saving the energies from VQE and Exact
for ind, file in enumerate(data_file_list):
    

    NW_data_file = str(os.path.join(root_dir,file))
    #NW_data_file = data_file_list[0]
    doc = open(NW_data_file, 'r')
    data = yml.load(doc, Loader)

    
    #Import all the data from a yaml file
    dist = 2 * data['integral_sets'][0]['geometry']['atoms'][1]['coords'][2]
    R.append(round(dist,3))
    moldata =  MolecularData(geometry=[('Li', (0, 0, 0)), ('Li', (0, 0, round(dist,3)))], basis='sto-3g', multiplicity=1,
                          description=str(dist), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
    string = 'Li' + " 0 0 0.0 \n" + 'Li' + " 0 0 " + str(round(dist,3)) + "\n" + "units ang \n" + "symmetry c1"
    mol = psi4.geometry(string)
    mol.set_multiplicity(1)
    psi4.set_options({'frozen_docc': [2], 'frozen_uocc' : [0]})
    mol.set_molecular_charge(0)

    hf_energy, hf_wavefunction = psi4.energy('hf/sto-3g', molecule=mol, return_wfn=True)
    print(round(dist,3),hf_energy)

    moldata.hf_energy = hf_energy
    moldata.nuclear_repulsion = mol.nuclear_repulsion_energy()
    moldata.canonical_orbitals = numpy.asarray(hf_wavefunction.Ca())
    moldata.n_orbitals = moldata.canonical_orbitals.shape[0]
    moldata.n_qubits = 2 * moldata.n_orbitals
    moldata.orbital_energies = numpy.asarray(hf_wavefunction.epsilon_a())
    moldata.fock_matrix = numpy.asarray(hf_wavefunction.Fa())

    mints = psi4.core.MintsHelper(hf_wavefunction.basisset())
    moldata.one_body_integrals = general_basis_change(
        numpy.asarray(mints.ao_kinetic()), moldata.canonical_orbitals, [0,0])
    moldata.one_body_integrals += general_basis_change(
        numpy.asarray(mints.ao_potential()), moldata.canonical_orbitals, [0,0])
    two_body_integrals = numpy.asarray(mints.ao_eri())
    two_body_integrals.reshape((moldata.n_orbitals, moldata.n_orbitals,
                              moldata.n_orbitals, moldata.n_orbitals))
    two_body_integrals = numpy.einsum('psqr', two_body_integrals)
    two_body_integrals = general_basis_change(two_body_integrals, moldata.canonical_orbitals, [0,0,0,0])

    moldata.two_body_integrals = two_body_integrals
    moldata.save()

    occupied_index = range(moldata.n_electrons//2 - 1)
    active_index = range(moldata.n_electrons//2 - 1, moldata.n_electrons//2 + 1)
    if dist < 1.80:
        active_index = [2,5]
    fermion_hamiltonian = get_fermion_operator(moldata.get_molecular_hamiltonian(
        occupied_indices=occupied_index, active_indices=active_index))
    hamiltonian = clean_qubits(bravyi_kitaev(fermion_hamiltonian), [1,3])
    for term, coefficient in hamiltonian.terms.items():
        if term == ():
            Base.append(coefficient.real)
        if term == ((0, 'Z'), (2, 'Z')):
            Z0Z1.append(coefficient.real)
        if term == ((0, 'X'), (2, 'X')):
            X0X1.append(coefficient.real)
        if term == ((0, 'Y'), (2, 'Y')):
            Y0Y1.append(coefficient.real)
        if term == ((2, 'Z'),):
            Z1.append(coefficient.real)
        if term == ((0, 'Z'),):
            Z0.append(coefficient.real)
print(' R   Base     Z0      Z1      Z0Z1     X0X1     Y0Y1')
for rv, bv, z0v, z1v, z0z1v, x0x1v, y0y1v in zip(R,Base,Z0,Z1,Z0Z1,X0X1,Y0Y1):
    print(rv, bv, z0v, z1v, z0z1v, x0x1v, y0y1v)
print('\n\n')
# Out:
# Found directory: /Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS
# 2.138 -14.621690942812052
# 2.272 -14.629719961363822
# 2.406 -14.634933469678895
# 2.539 -14.637825678487172
# 2.673 -14.638882063543832
# 2.807 -14.63844824150032
# 2.94 -14.63685048514371
# 3.074 -14.634317887850745
# 3.208 -14.63106685090352
# 3.341 -14.627298133017973
# 4.01 -14.604270698558091
# 4.678 -14.58084637555083
# 5.346 -14.561136733697612
# 6.683 -14.536071387229569
# 13.365 -14.509845151137753
#  R   Base     Z0      Z1      Z0Z1     X0X1     Y0Y1
# 2.138 -14.314507951731956 0.09742012801841912 -0.008489634301612394 0.20111473244209138 0.02093353643964756 0.02093353643964756
# 2.272 -14.325916908877439 0.0971350627259379 -0.008355847190463745 0.19815431974287803 0.020483401918384873 0.020483401918384873
# 2.406 -14.335488341082197 0.09630092066168838 -0.007838966690678798 0.1951479374558805 0.020313210547643692 0.020313210547643692
# ...

# %% [markdown]
# # STO-6G Google Style - Frozen Core - 1 Virtual

# %%
import psi4
import numpy 
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator, InteractionOperator
import yaml as yml
from yaml import SafeLoader as Loader
import os

def clean_qubits(qubit_operator, removables):
    new_qubit_operator = QubitOperator()
    for term, coefficient in qubit_operator.terms.items():
        term = list(term)
        for item in reversed(range(len(term))):
            if term[item][0] in removables and term[item][1] == 'Z':
                del term[item]
        new_qubit_operator += QubitOperator(tuple(term), coefficient)
    return (new_qubit_operator) 

def reduce_jw(qubit_operator):
    g0 = 0
    g1 = 0
    g2 = 0
    g3 = 0
    for term, coefficient in qubit_operator.terms.items():
        if term == ():
            g0 += coefficient
        if term == ((0, 'Z'), (2, 'Z')):
            g0 -= 2*coefficient
        if term == ((1, 'Z'), (2, 'Z')):
            g1 -= 2*coefficient
        if term == ((0, 'Y'), (1, 'X'), (2, 'X'), (3, 'Y')):
            g2 += 4*coefficient
        if term == ((2, 'Z'), (3, 'Z')):
            g1 += coefficient
        if term == ((0, 'Z'), (1, 'Z')):
            g1 += coefficient
        if term == ((2, 'Z'),):
            g3 += coefficient
        if term == ((0, 'Z'),):
            g3 -= coefficient
    new_qubit_operator = QubitOperator((), g0)
    new_qubit_operator += QubitOperator(((0, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((1, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((0, 'X'), (1, 'X')), g2)
    new_qubit_operator += QubitOperator(((0, 'Z'), (1, 'Z')), g1)
    return new_qubit_operator

#################### WALK ROOT DIR ############################
root_dir = '/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS'
data_file_list = []

for dirName, subdirList, fileList in os.walk(root_dir):
    print('Found directory: %s' % dirName)
    for fname in sorted(fileList):
        if fname.endswith('.yaml'):
            data_file_list.append(fname)

#Erasing list to check with H2
#data_file_list = ['H2.yaml']
###############################################################

atoms = ['Li']
equil = [2.67]
for atomid, dist in zip(atoms, equil):
    R = []
    Base = []
    Z0 = []
    Z1 = []
    Z0Z1 = []
    X0X1 = []
    Y0Y1 = []
    print(atomid+"2 data with Re = ",dist)
    for point in arange(0.1, dist+3.0, 0.05):
        R.append(round(point,2))
        moldata =  MolecularData(geometry=[(atomid, (0, 0, 0)), (atomid, (0, 0, round(point,2)))], basis='sto-6g', multiplicity=1,
                          description=str(round(point, 2)), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
        string = atomid + " 0 0 0.0 \n" + atomid + " 0 0 " + str(round(point,2)) + "\n" + "units ang \n" + "symmetry c1"
        mol = psi4.geometry(string)
        mol.set_multiplicity(1)
        mol.set_molecular_charge(0)

        hf_energy, hf_wavefunction = psi4.energy('hf/sto-6g', molecule=mol, return_wfn=True)

        moldata.hf_energy = hf_energy
        moldata.nuclear_repulsion = mol.nuclear_repulsion_energy()
        moldata.canonical_orbitals = numpy.asarray(hf_wavefunction.Ca())
        moldata.n_orbitals = moldata.canonical_orbitals.shape[0]
        moldata.n_qubits = 2 * moldata.n_orbitals
        moldata.orbital_energies = numpy.asarray(hf_wavefunction.epsilon_a())
        moldata.fock_matrix = numpy.asarray(hf_wavefunction.Fa())

        mints = psi4.core.MintsHelper(hf_wavefunction.basisset())
        moldata.one_body_integrals = general_basis_change(
            numpy.asarray(mints.ao_kinetic()), moldata.canonical_orbitals, [0,0])
        moldata.one_body_integrals += general_basis_change(
            numpy.asarray(mints.ao_potential()), moldata.canonical_orbitals, [0,0])
        two_body_integrals = numpy.asarray(mints.ao_eri())
        two_body_integrals.reshape((moldata.n_orbitals, moldata.n_orbitals,
                                    moldata.n_orbitals, moldata.n_orbitals))
        two_body_integrals = numpy.einsum('psqr', two_body_integrals)
        two_body_integrals = general_basis_change(two_body_integrals, moldata.canonical_orbitals, [0,0,0,0])

        moldata.two_body_integrals = two_body_integrals
        moldata.save()

        occupied_index = range(moldata.n_electrons//2 - 1)
        active_index = range(moldata.n_electrons//2 - 1, moldata.n_electrons//2 + 1)
        if dist < 1.80 and atomid == 'Li':
            active_index = [2,5]
        fermion_hamiltonian = get_fermion_operator(moldata.get_molecular_hamiltonian(
            occupied_indices=occupied_index, active_indices=active_index))
        hamiltonian = clean_qubits(bravyi_kitaev(fermion_hamiltonian), [1,3])
        for term, coefficient in hamiltonian.terms.items():
            if term == ():
                Base.append(coefficient.real)
            if term == ((0, 'Z'), (2, 'Z')):
                Z0Z1.append(coefficient.real)
            if term == ((0, 'X'), (2, 'X')):
                X0X1.append(coefficient.real)
            if term == ((0, 'Y'), (2, 'Y')):
                Y0Y1.append(coefficient.real)
            if term == ((2, 'Z'),):
                Z1.append(coefficient.real)
            if term == ((0, 'Z'),):
                Z0.append(coefficient.real)
    print(' R   Base     Z0      Z1      Z0Z1     X0X1     Y0Y1')
    for rv, bv, z0v, z1v, z0z1v, x0x1v, y0y1v in zip(R,Base,Z0,Z1,Z0Z1,X0X1,Y0Y1):
        print(rv, bv, z0v, z1v, z0z1v, x0x1v, y0y1v)
    print('\n\n')
# Out:
# Found directory: /Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS
# Li2 data with Re =  2.67
#  R   Base     Z0      Z1      Z0Z1     X0X1     Y0Y1
# 0.1 20.778194284610954 0.3470360952908803 -0.12260160510266079 0.25037278741378877 0.009409858377405206 0.009409858377405206
# 0.15 5.823720473239017 0.32252498098539184 -0.08740496271049995 0.2435424033614358 0.011936457323601081 0.011936457323601081
# 0.2 -1.2761278236715718 0.2954277582010473 -0.058660143133980186 0.23834589334375805 0.01490753986083362 0.01490753986083362
# 0.25 -5.3341290203703515 0.2685596088198966 -0.0380215685162803 0.23465160778995775 0.017937461786477028 0.017937461786477028
# 0.3 -7.922358930452377 0.24458827812006667 -0.023600722905198847 0.23189262410618589 0.02073139383354824 0.02073139383354824
# 0.35 -9.681507866202049 0.2246442043456695 -0.01324076394151253 0.22963938966802652 0.02313800188979048 0.02313800188979048
# ...

# %% [markdown]
# # CC-PVTZ Google Style - Frozen Core - 1 Virtual

# %%
import psi4
import numpy 
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator, InteractionOperator
import yaml as yml
from yaml import SafeLoader as Loader
import os

def clean_qubits(qubit_operator, removables):
    new_qubit_operator = QubitOperator()
    for term, coefficient in qubit_operator.terms.items():
        term = list(term)
        for item in reversed(range(len(term))):
            if term[item][0] in removables and term[item][1] == 'Z':
                del term[item]
        new_qubit_operator += QubitOperator(tuple(term), coefficient)
    return (new_qubit_operator) 

def reduce_jw(qubit_operator):
    g0 = 0
    g1 = 0
    g2 = 0
    g3 = 0
    for term, coefficient in qubit_operator.terms.items():
        if term == ():
            g0 += coefficient
        if term == ((0, 'Z'), (2, 'Z')):
            g0 -= 2*coefficient
        if term == ((1, 'Z'), (2, 'Z')):
            g1 -= 2*coefficient
        if term == ((0, 'Y'), (1, 'X'), (2, 'X'), (3, 'Y')):
            g2 += 4*coefficient
        if term == ((2, 'Z'), (3, 'Z')):
            g1 += coefficient
        if term == ((0, 'Z'), (1, 'Z')):
            g1 += coefficient
        if term == ((2, 'Z'),):
            g3 += coefficient
        if term == ((0, 'Z'),):
            g3 -= coefficient
    new_qubit_operator = QubitOperator((), g0)
    new_qubit_operator += QubitOperator(((0, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((1, 'Z'),), g3)
    new_qubit_operator += QubitOperator(((0, 'X'), (1, 'X')), g2)
    new_qubit_operator += QubitOperator(((0, 'Z'), (1, 'Z')), g1)
    return new_qubit_operator

#################### WALK ROOT DIR ############################
root_dir = '/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS'
data_file_list = []

for dirName, subdirList, fileList in os.walk(root_dir):
    print('Found directory: %s' % dirName)
    for fname in sorted(fileList):
        if fname.endswith('.yaml'):
            data_file_list.append(fname)

#Erasing list to check with H2
#data_file_list = ['H2.yaml']
###############################################################
R = []
Base = []
Z0 = []
Z1 = []
Z0Z1 = []
X0X1 = []
Y0Y1 = []


#Looping over all of the yaml files in a particular directory and saving the energies from VQE and Exact
for ind, file in enumerate(data_file_list):
    

    NW_data_file = str(os.path.join(root_dir,file))
    #NW_data_file = data_file_list[0]
    doc = open(NW_data_file, 'r')
    data = yml.load(doc, Loader)

    
    #Import all the data from a yaml file
    dist = 2 * data['integral_sets'][0]['geometry']['atoms'][1]['coords'][2]
    R.append(round(dist,3))
    moldata =  MolecularData(geometry=[('Li', (0, 0, 0)), ('Li', (0, 0, round(dist,3)))], basis='cc-pvtz', multiplicity=1,
                          description=str(dist), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
    string = 'Li' + " 0 0 0.0 \n" + 'Li' + " 0 0 " + str(round(dist,3)) + "\n" + "units ang \n" + "symmetry c1"
    mol = psi4.geometry(string)
    mol.set_multiplicity(1)
    psi4.set_options({'frozen_docc': [2], 'frozen_uocc' : [56]})
    mol.set_molecular_charge(0)

    hf_energy, hf_wavefunction = psi4.energy('hf/cc-pvtz', molecule=mol, return_wfn=True)
    print(round(dist,3),hf_energy)

    moldata.hf_energy = hf_energy
    moldata.nuclear_repulsion = mol.nuclear_repulsion_energy()
    moldata.canonical_orbitals = numpy.asarray(hf_wavefunction.Ca())
    moldata.n_orbitals = moldata.canonical_orbitals.shape[0]
    moldata.n_qubits = 2 * moldata.n_orbitals
    moldata.orbital_energies = numpy.asarray(hf_wavefunction.epsilon_a())
    moldata.fock_matrix = numpy.asarray(hf_wavefunction.Fa())

    mints = psi4.core.MintsHelper(hf_wavefunction.basisset())
    moldata.one_body_integrals = general_basis_change(
        numpy.asarray(mints.ao_kinetic()), moldata.canonical_orbitals, [0,0])
    moldata.one_body_integrals += general_basis_change(
        numpy.asarray(mints.ao_potential()), moldata.canonical_orbitals, [0,0])
    two_body_integrals = numpy.asarray(mints.ao_eri())
    two_body_integrals.reshape((moldata.n_orbitals, moldata.n_orbitals,
                              moldata.n_orbitals, moldata.n_orbitals))
    two_body_integrals = numpy.einsum('psqr', two_body_integrals)
    two_body_integrals = general_basis_change(two_body_integrals, moldata.canonical_orbitals, [0,0,0,0])

    moldata.two_body_integrals = two_body_integrals
    moldata.save()

    occupied_index = range(moldata.n_electrons//2 - 1)
    active_index = range(moldata.n_electrons//2 - 1, moldata.n_electrons//2 + 1)
    if point < 1.80:
        active_index = [2,5]
    fermion_hamiltonian = get_fermion_operator(moldata.get_molecular_hamiltonian(
        occupied_indices=occupied_index, active_indices=active_index))
    hamiltonian = clean_qubits(bravyi_kitaev(fermion_hamiltonian), [1,3])
    for term, coefficient in hamiltonian.terms.items():
        if term == ():
            Base.append(coefficient.real)
        if term == ((0, 'Z'), (2, 'Z')):
            Z0Z1.append(coefficient.real)
        if term == ((0, 'X'), (2, 'X')):
            X0X1.append(coefficient.real)
        if term == ((0, 'Y'), (2, 'Y')):
            Y0Y1.append(coefficient.real)
        if term == ((2, 'Z'),):
            Z1.append(coefficient.real)
        if term == ((0, 'Z'),):
            Z0.append(coefficient.real)
print(' R   Base     Z0      Z1      Z0Z1     X0X1     Y0Y1')
for rv, bv, z0v, z1v, z0z1v, x0x1v, y0y1v in zip(R,Base,Z0,Z1,Z0Z1,X0X1,Y0Y1):
    print(rv, bv, z0v, z1v, z0z1v, x0x1v, y0y1v)
print('\n\n')
# Out:
# Found directory: /Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks/4_ORBITALS
# 2.138 -14.854274331265596
# 2.272 -14.86172570209899
# 2.406 -14.866744725988449
# 2.539 -14.869800497620274
# 2.673 -14.87134549393934
# 2.807 -14.871686249478769
# 2.94 -14.871102330127655
# 3.074 -14.869802424471203
# 3.208 -14.867962672345062
# 3.341 -14.865740111440537
# 4.01 -14.8516961449799
# 4.678 -14.837162719281928
# 5.346 -14.824410024685218
# 6.683 -14.80539302469082
# 13.365 -14.774969323241217
#  R   Base     Z0      Z1      Z0Z1     X0X1     Y0Y1
# 2.138 -14.596067447218239 0.18388752166998235 0.056484292670890814 0.1308001870477826 0.007499392269831359 0.007499392269831359
# 2.272 -14.607282879784425 0.18068596566129158 0.05672403805512912 0.13047733802748251 0.007673668649230395 0.007673668649230395
# 2.406 -14.616703980477427 0.17694089452871034 0.057172415180657514 0.1302686188577109 0.007957788259158103 0.007957788259158103
# ...

# %% [markdown]
# # Classical energies, STO-3G - Frozen Core - All Virtuals

# %%
import psi4
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator

atoms = ['Li']
equil = [2.67]

for atomid, dist in zip(atoms, equil):
    print(atomid+"2 data with Re = ",dist, " sto-6g")
    print('R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization')
    for point in arange(0.1, dist+3.0, 0.05):
        moldata =  MolecularData(geometry=[(atomid, (0, 0, 0)), (atomid, (0, 0, round(point,2)))], basis='sto-6g', multiplicity=1,
                          description=str(round(point, 2)), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
        string = atomid + " 0 0 0.0 \n" + atomid + " 0 0 " + str(round(point,2)) + "\n" + "units ang \n" + "symmetry c1"
        mol = psi4.geometry(string)
        mol.set_multiplicity(1)
        mol.set_molecular_charge(0)

        hf_energy = psi4.energy('hf/sto-6g', molecule=mol, return_wfn=False)
        #psi4.set_options({'frozen_docc' : '2', 'frozen_uocc' : '6', 'num_roots', })
        psi4.set_options({'frozen_docc' : [2], 'frozen_uocc' : [0], 'num_roots' : 4})
        ci_energy = psi4.energy('fci/sto-6g', molecule=mol, return_wfn=False)

        print(round(point,2), hf_energy, ci_energy )
    print('\n\n')
# Out:
# Li2 data with Re =  2.67  sto-6g
# R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization
# 0.1 20.058023198507748 20.02777444226534
# 0.15 5.170274653440994 5.137863749946558
# 0.2 -1.8683384477076155 -1.9030700188125245
# 0.25 -5.874987754248373 -5.911916429269592
# 0.3 -8.421940980786793 -8.46083927304237
# 0.35 -10.148433479785892 -10.189073887278674
# 0.4 -11.359709396396408 -11.401919630160934
# 0.45 -12.225406141481162 -12.269021306717338
# 0.5 -12.851132875183495 -12.896014957195565
# 0.55 -13.307048315302245 -13.353130920561371
# 0.6 -13.64140240455246 -13.688657009098982
# 0.65 -13.888035703143142 -13.936436699996374
# 0.7 -14.070992000121954 -14.120505019487682
# 0.75 -14.20752455233457 -14.25810361825041
# 0.8 -14.310113562122549 -14.361698896703892
# 0.85 -14.387845454338906 -14.440359789229099
# 0.9 -14.447368931236646 -14.500713047602277
# 0.95 -14.493566240170036 -14.547615220107904
# 1.0 -14.530030565097778 -14.584631774881734
# ...

# %% [markdown]
# # Classical energies, STO-3G - Frozen Core - 1 Virtual

# %%
import psi4
import numpy as np
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator

atoms = ['Li']
equil = [2.67]

points = [2.138, 2.272, 2.406, 2.539, 2.673, 2.807, 2.94, 3.074, 3.208, 3.341, 4.01, 4.678, 5.346, 6.683, 13.365]

for atomid, dist in zip(atoms, equil):
    print(atomid+"2 data with Re = ",dist, " sto-3g")
    print('R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization')
    for point in points:
        moldata =  MolecularData(geometry=[(atomid, (0, 0, 0)), (atomid, (0, 0, round(point,2)))], basis='sto-3g', multiplicity=1,
                          description=str(round(point, 2)), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
        string = atomid + " 0 0 0.0 \n" + atomid + " 0 0 " + str(round(point,2)) + "\n" + "units ang \n" + "symmetry c1"
        mol = psi4.geometry(string)
        mol.set_multiplicity(1)
        mol.set_molecular_charge(0)

        hf_energy = psi4.energy('hf/sto-3g', molecule=mol, return_wfn=False)
        #psi4.set_options({'frozen_docc' : '2', 'frozen_uocc' : '6', 'num_roots', })
        psi4.set_options({'frozen_docc' : [2], 'frozen_uocc' : [6], 'num_roots' : 1})
        ccsd_energy = psi4.energy('ccsd/sto-3g', molecule=mol, return_wfn=False)
        ci_energy = psi4.energy('fci/sto-3g', molecule=mol, return_wfn=False)

        print(round(point,2), hf_energy, ccsd_energy, ci_energy )
    print('\n\n')
# Out:
# Li2 data with Re =  2.67  sto-3g
# R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization
# 2.14 -14.621834119694908 -14.629643800510093 -14.629643796008487
# 2.27 -14.62962215475217 -14.637141964233912 -14.637141960538885
# 2.41 -14.635051256571222 -14.642540397926435 -14.642540394317729
# 2.54 -14.637839961496947 -14.645519152542613 -14.645519148445741
# 2.67 -14.638875995689872 -14.646933675674747 -14.646933675675378
# 2.81 -14.638423982748694 -14.6470918401503 -14.647091840163103
# 2.94 -14.636850485143706 -14.646276580304642 -14.646276580355378
# 3.07 -14.63440482645463 -14.644785135337495 -14.644785135478863
# 3.21 -14.631013796378205 -14.642660227853112 -14.642660228225784
# 3.34 -14.627328125852006 -14.640393450536221 -14.640393451389498
# 4.01 -14.604270698558082 -14.629086807236012 -14.629086805902407
# 4.68 -14.580780692193457 -14.624485387443956 -14.624485388367104
# 5.35 -14.561033277922418 -14.625491840154629 -14.625491842428692
# ...

# %% [markdown]
# # Classical energies, STO-3G - Frozen Core - 1 Virtual

# %%
import psi4
import numpy as np
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator

atoms = ['Li']
equil = [2.67]

points = [2.138, 2.272, 2.406, 2.539, 2.673, 2.807, 2.94, 3.074, 3.208, 3.341, 4.01, 4.678, 5.346, 6.683, 13.365]

for atomid, dist in zip(atoms, equil):
    print(atomid+"2 data with Re = ",dist, " sto-3g")
    print('R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization')
    for point in points:
        moldata =  MolecularData(geometry=[(atomid, (0, 0, 0)), (atomid, (0, 0, round(point,2)))], basis='sto-3g', multiplicity=1,
                          description=str(round(point, 2)), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
        string = atomid + " 0 0 0.0 \n" + atomid + " 0 0 " + str(round(point,2)) + "\n" + "units ang \n" + "symmetry c1"
        mol = psi4.geometry(string)
        mol.set_multiplicity(1)
        mol.set_molecular_charge(0)

        hf_energy = psi4.energy('hf/sto-3g', molecule=mol, return_wfn=False)
        #psi4.set_options({'frozen_docc' : '2', 'frozen_uocc' : '6', 'num_roots', })
        psi4.set_options({'frozen_docc' : [0], 'frozen_uocc' : [6], 'num_roots' : 1})
        ccsd_energy = psi4.energy('ccsd/sto-3g', molecule=mol, return_wfn=False)
        ci_energy = psi4.energy('fci/sto-3g', molecule=mol, return_wfn=False)

        print(round(point,2), hf_energy, ccsd_energy, ci_energy )
    print('\n\n')
# Out:
# Li2 data with Re =  2.67  sto-3g
# R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization
# 2.14 -14.621834119694928 -14.629682746762267 -14.629682748295057
# 2.27 -14.629622154752155 -14.637183317184398 -14.637183318475861
# 2.41 -14.635051256571217 -14.642583789295621 -14.642583790529509
# 2.54 -14.637839961496951 -14.645564130988939 -14.645564132316673
# 2.67 -14.638875995689862 -14.646980050447553 -14.646980052022823
# 2.81 -14.638423982748696 -14.64713953549839 -14.647139537574716
# 2.94 -14.636850485143714 -14.64632533520813 -14.646325338080379
# 3.07 -14.63440482645463 -14.644834767158928 -14.644834771330764
# 3.21 -14.631013796378193 -14.642710567719714 -14.642710567549441
# 3.34 -14.627328125852 -14.640444178012634 -14.640444177781776
# 4.01 -14.604270698558082 -14.629134450980333 -14.629134449149266
# 4.68 -14.580780692193454 -14.624523690552415 -14.624523691120919
# 5.35 -14.561033277922421 -14.625522120447535 -14.625522122218188
# ...

# %% [markdown]
# # Classical energies, STO-6G - Frozen Core - 1 Virtual

# %%
import psi4
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator

atoms = ['Li']
equil = [2.67]

points = [2.138, 2.272, 2.406, 2.539, 2.673, 2.807, 2.94, 3.074, 3.208, 3.341, 4.01, 4.678, 5.346, 6.683, 13.365]

for atomid, dist in zip(atoms, equil):
    print(atomid+"2 data with Re = ",dist, " sto-6g")
    print('R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization')
    for point in points:
        moldata =  MolecularData(geometry=[(atomid, (0, 0, 0)), (atomid, (0, 0, round(point,2)))], basis='sto-6g', multiplicity=1,
                          description=str(round(point, 2)), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
        string = atomid + " 0 0 0.0 \n" + atomid + " 0 0 " + str(round(point,2)) + "\n" + "units ang \n" + "symmetry c1"
        mol = psi4.geometry(string)
        mol.set_multiplicity(1)
        mol.set_molecular_charge(0)

        hf_energy = psi4.energy('hf/sto-6g', molecule=mol, return_wfn=False)
        #psi4.set_options({'frozen_docc' : '2', 'frozen_uocc' : '6', 'num_roots', })
        psi4.set_options({'frozen_docc' : [2], 'frozen_uocc' : [6], 'num_roots' : 1})
        ccsd_energy = psi4.energy('ccsd/sto-6g', molecule=mol, return_wfn=False)
        ci_energy = psi4.energy('fci/sto-6g', molecule=mol, return_wfn=False)

        print(round(point,2), hf_energy, ccsd_energy, ci_energy )
    print('\n\n')
# Out:
# Li2 data with Re =  2.67  sto-6g
# R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization
# 2.14 -14.792456200007127 -14.800021455228203 -14.800021451876987
# 2.27 -14.800036451910007 -14.807351929668805 -14.807351926856649
# 2.41 -14.805284231086631 -14.812596692483226 -14.812596689680865
# 2.54 -14.807945104494856 -14.81545984268295 -14.815459839459136
# 2.67 -14.808888374096792 -14.816782132930843 -14.816782128779135
# 2.81 -14.808368821317686 -14.816861036050618 -14.81686103602393
# 2.94 -14.806755621635471 -14.815983846814742 -14.815983846804153
# 3.07 -14.804285583933895 -14.8144344785217 -14.8144344785659
# 3.21 -14.80087792739109 -14.812243696566464 -14.812243696780603
# 3.34 -14.797179048481084 -14.8099058911839 -14.809905891743169
# 4.01 -14.773906591803549 -14.79800707914024 -14.798007078078399
# 4.68 -14.749908585054808 -14.792932566670595 -14.792932567409716
# 5.35 -14.729816205341878 -14.794004120247877 -14.794004122320354
# ...

# %% [markdown]
# # Classical energies, STO-6G - All electrons correlated - 1 Virtual

# %%
import psi4
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator

atoms = ['Li']
equil = [2.67]

points = [2.138, 2.272, 2.406, 2.539, 2.673, 2.807, 2.94, 3.074, 3.208, 3.341, 4.01, 4.678, 5.346, 6.683, 13.365]

for atomid, dist in zip(atoms, equil):
    print(atomid+"2 data with Re = ",dist, " sto-6g")
    print('R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization')
    for point in points:
        moldata =  MolecularData(geometry=[(atomid, (0, 0, 0)), (atomid, (0, 0, round(point,2)))], basis='sto-6g', multiplicity=1,
                          description=str(round(point, 2)), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
        string = atomid + " 0 0 0.0 \n" + atomid + " 0 0 " + str(round(point,2)) + "\n" + "units ang \n" + "symmetry c1"
        mol = psi4.geometry(string)
        mol.set_multiplicity(1)
        mol.set_molecular_charge(0)

        hf_energy = psi4.energy('hf/sto-6g', molecule=mol, return_wfn=False)
        #psi4.set_options({'frozen_docc' : '2', 'frozen_uocc' : '6', 'num_roots', })
        psi4.set_options({'frozen_docc' : [0], 'frozen_uocc' : [6], 'num_roots' : 1})
        ccsd_energy = psi4.energy('ccsd/sto-6g', molecule=mol, return_wfn=False)
        ci_energy = psi4.energy('fci/sto-6g', molecule=mol, return_wfn=False)

        print(round(point,2), hf_energy, ccsd_energy, ci_energy )
    print('\n\n')
# Out:
# Li2 data with Re =  2.67  sto-6g
# R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization
# 2.14 -14.79245620000713 -14.800065104506547 -14.800065105682382
# 2.27 -14.800036451910014 -14.807398029521687 -14.807398030529233
# 2.41 -14.80528423108662 -14.812645021422169 -14.812645022394628
# 2.54 -14.807945104494852 -14.815509964574499 -14.815509965624573
# 2.67 -14.808888374096782 -14.816833831308847 -14.81683383255466
# 2.81 -14.808368821317675 -14.816914214500759 -14.816914216141011
# 2.94 -14.806755621635473 -14.816038183504443 -14.816038185772593
# 3.07 -14.804285583933897 -14.81448974902356 -14.814489752319972
# 3.21 -14.80087792739107 -14.812299693836893 -14.812299693649047
# 3.34 -14.797179048481091 -14.809962261461276 -14.809962261220084
# 4.01 -14.773906591803545 -14.798059883815695 -14.798059882342201
# 4.68 -14.749908585054808 -14.792974869252994 -14.792974869670894
# 5.35 -14.729816205341862 -14.79403735948657 -14.79403735969562
# ...

# %% [markdown]
# # Classical energies, CC-PVTZ - Frozen Core - 1 Virtual

# %%
import psi4
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator
import numpy as np

atoms = ['Li']
equil = [2.67]

points = [2.138, 2.272, 2.406, 2.539, 2.673, 2.807, 2.94, 3.074, 3.208, 3.341, 4.01, 4.678, 5.346, 6.683, 13.365]

for atomid, dist in zip(atoms, equil):
    print(atomid+"2 data with Re = ",dist, " sto-6g")
    print('R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization')
    for point in points:
        moldata =  MolecularData(geometry=[(atomid, (0, 0, 0)), (atomid, (0, 0, round(point,2)))], basis='cc-pvtz', multiplicity=1,
                          description=str(round(point, 2)), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
        string = atomid + " 0 0 0.0 \n" + atomid + " 0 0 " + str(round(point,2)) + "\n" + "units ang \n" + "symmetry c1"
        mol = psi4.geometry(string)
        mol.set_multiplicity(1)
        mol.set_molecular_charge(0)

        hf_energy = psi4.energy('hf/cc-pvtz', molecule=mol, return_wfn=False)
        #psi4.set_options({'frozen_docc' : '2', 'frozen_uocc' : '6', 'num_roots', })
        psi4.set_options({'frozen_docc' : [2], 'frozen_uocc' : [56], 'num_roots' : 1})
        ccsd_energy = psi4.energy('ccsd/cc-pvtz', molecule=mol, return_wfn=False)
        ci_energy = psi4.energy('fci/cc-pvtz', molecule=mol, return_wfn=False)

        print(round(point,2), hf_energy, ccsd_energy, ci_energy )
    print('\n\n')
# Out:
# Li2 data with Re =  2.67  sto-6g
# R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization
# 0.1 16.650217603036513 16.650558707541755 16.650558708520343
# 0.15 2.6943899699129936 2.6933279395295284 2.6933279395706897
# 0.2 -3.588390224233971 -3.590704023162775 -3.5907040232175227
# 0.25 -7.032650114896104 -7.036856425561091 -7.036856425563215
# 0.3 -9.184629403195004 -9.191050475526476 -9.19105047513647
# 0.35 -10.64400066625773 -10.652560583217713 -10.652560580934814
# 0.4 -11.679485814324222 -11.689914943663423 -11.689914943822677
# 0.45 -12.432188420785145 -12.444074986573558 -12.444074987266177
# 0.5 -12.986969494318167 -12.99992773256806 -12.999927734502219
# 0.55 -13.399535596060767 -13.413339420332012 -13.413339424799661
# 0.6 -13.70841815020091 -13.722920897109839 -13.722920896935854
# 0.65 -13.941021613081336 -13.956088165283376 -13.956088165400384
# 0.7 -14.117147989886657 -14.132642237363358 -14.132642237313727
# ...

# %% [markdown]
# # Classical energies CC-PVTZ, All electrons correlated - 1 Virtual

# %%
import psi4
from numpy import array, arange
from openfermion.hamiltonians import MolecularData
from openfermion.ops._polynomial_tensor import general_basis_change
from openfermion.transforms import get_fermion_operator, jordan_wigner, bravyi_kitaev
from openfermion.transforms import bravyi_kitaev_fast, bravyi_kitaev_tree, get_sparse_operator
from openfermion.ops import QubitOperator
import numpy as np

atoms = ['Li']
equil = [2.67]

points = [2.138, 2.272, 2.406, 2.539, 2.673, 2.807, 2.94, 3.074, 3.208, 3.341, 4.01, 4.678, 5.346, 6.683, 13.365]

for atomid, dist in zip(atoms, equil):
    print(atomid+"2 data with Re = ",dist, " sto-6g")
    print('R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization')
    for point in points:
        moldata =  MolecularData(geometry=[(atomid, (0, 0, 0)), (atomid, (0, 0, round(point,2)))], basis='cc-pvtz', multiplicity=1,
                          description=str(round(point, 2)), filename="moldata", 
                          data_directory="/Users/wadejong/Desktop/Quantum-Computing/QCQCSiddiqi/Circuit_Notebooks")
        string = atomid + " 0 0 0.0 \n" + atomid + " 0 0 " + str(round(point,2)) + "\n" + "units ang \n" + "symmetry c1"
        mol = psi4.geometry(string)
        mol.set_multiplicity(1)
        mol.set_molecular_charge(0)

        hf_energy = psi4.energy('hf/cc-pvtz', molecule=mol, return_wfn=False)
        #psi4.set_options({'frozen_docc' : '2', 'frozen_uocc' : '6', 'num_roots', })
        psi4.set_options({'frozen_docc' : [0], 'frozen_uocc' : [56], 'num_roots' : 1})
        ccsd_energy = psi4.energy('ccsd/cc-pvtz', molecule=mol, return_wfn=False)
        ci_energy = psi4.energy('fci/cc-pvtz', molecule=mol, return_wfn=False)

        print(round(point,2), hf_energy, ccsd_energy, ci_energy )
    print('\n\n')
# Out:
# Li2 data with Re =  2.67  sto-6g
# R       Hartree-Fock       CCSD         Full-CI/Exact diagonalization
# 2.14 -14.854406055428939 -14.855283699015796 -14.85528369979934
# 2.27 -14.861633671626336 -14.86257607378141 -14.862576073782718
# 2.41 -14.86686240762576 -14.867916566417914 -14.867916566405144
# 2.54 -14.869817271000068 -14.87101580242636 -14.871015802395464
# 2.67 -14.871325211273097 -14.872710857945014 -14.87271085788922
# 2.81 -14.871682305533648 -14.873323267659458 -14.873323267563979
# 2.94 -14.871102330127645 -14.873037359323757 -14.87303735916993
# 3.07 -14.869849818809543 -14.872141693691145 -14.872141693440184
# 3.21 -14.867931871529084 -14.870688096296028 -14.870688095854613
# 3.34 -14.865758012568218 -14.869029568913113 -14.869029568133667
# 4.01 -14.8516961449799 -14.859270777193634 -14.859270776386762
# 4.68 -14.837121387586055 -14.85238733919306 -14.852387338849523
# 5.35 -14.824340353710994 -14.850083262547207 -14.850083250780765
# ...
